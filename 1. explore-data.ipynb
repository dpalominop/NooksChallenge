# %%
import pandas as pd

# %%
pd.read_csv('data/train_data.csv')
# Out:
#       Unnamed: 0                                 sid      label  \
# 0              0  CF8e49eff05aa1505fd419f4b3183e6898      human
# 1              1  CF78c33ca4e5d8a1fefbbd814b0b77912a  voicemail
# 2              2  CF374e99cf5e643b84243a908d45429bf6  voicemail
# 3              3  CF357bb78d1787f6a9e461ab1f229890c8      human
# 4              4  CF000ffa4ef2954b2b22ae5278033b7bb9      human
# ...          ...                                 ...        ...
# 2913        2913  CF0651f63da6f2ea02f18d7cf6c9efafc8  voicemail
# 2914        2914  CFb10e29e754bf876678745028dee8278b      human
# 2915        2915  CF9b1e586eb99588d63b7244f4da31f9ea  voicemail
# 2916        2916  CF5eb6d8cc9cb4b2e482dee49b5501aa3f      human
# 2917        2917  CF1850bcacfcb1440aa0f7420a17e201c7  voicemail
#
#                                              transcript  \
# 0                                       Hey, what's up?
# 1     Hi, this is Frank Apple. I'm unable to take yo...
# ...

# %%
# note that this doesn't have labels, but the format is the same
# Your goal is to return a CSV file - evaluation_predictions.csv - that has the predictions for each call in the eval set
pd.read_csv('data/evaluation_data.csv')
# Out:
#      Unnamed: 0                                 sid  \
# 0             0  CF8fd2e7ac0e4ff2316bb18a9ffe5e9e68
# 1             1  CF2a9819f31261b93230e2ad68888bb479
# 2             2  CF94166971f53d5b09ac2e411755ead266
# 3             3  CF13315d4973c7c6333ed31aac7b406f46
# 4             4  CFd61f7d8a06b913c4b2170bebe99b3331
# ..          ...                                 ...
# 725         725  CFa21859e752416d642f9d93aa1c290f66
# 726         726  CF5d58b2164c51a9ec5295e48c16beca5c
# 727         727  CFf631ae0c49dc94fd43ae77da07c233e5
# 728         728  CFc52805d7b70ebf85c0a924d3f2ef6749
# 729         729  CF14cc041738be486351ad2e13da6cc80b
#
#                                             transcript  \
# 0    Your call has been forwarded to an automated v...
# 1            Lamancha. This is Carrie. Can I help you?
# 2    Yes, so let me says hello, you've reached this...
# 3                                         Brian toner.
# 4    Hello, darling. Static is not available. Pleas...
# ...
